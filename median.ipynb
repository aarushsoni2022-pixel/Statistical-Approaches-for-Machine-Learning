# %%
#Median

k=[2,4,5,6,8,9,12,14,15,17,19]
print(f"{k[0]}\n{k[1]}\n{k[2]}\n{k[3]}\n{k[4]}\n{k[5]}\n{k[6]}\n{k[7]}\n{k[8]}\n{k[9]}\n{k[10]}")
# Out:
# 2
# 4
# 5
# 6
# 8
# 9
# 12
# 14
# 15
# 17
# 19

# %%
k=[2,4,5,6,8,9,12,14,15,17,19,21,22,23]
n=len(k)
print("len:",n)
# Out:
# len: 14

# %%
k=[2,4,5,6,8,9,12,14,15,17,19,21,22,23]
n=len(k)
midpos=n//2
print("Mid Position:",midpos)
print("Value of Middle Position:",k[midpos])
# Out:
# Mid Position: 7
# Value of Middle Position: 14

# %%
l=[12,14,15,16,18,19,22,24,25,27,29,39,40,42,45,47,49,19,21,22,23]
n=len(l)
midpos=n//2
print(l[0:18])
print("len:",n)
print("Mid Pos:",midpos)
print("Value of Mid Pos:",l[midpos])
# Out:
# [12, 14, 15, 16, 18, 19, 22, 24, 25, 27, 29, 39, 40, 42, 45, 47, 49, 19]
# len: 21
# Mid Pos: 10
# Value of Mid Pos: 29

# %%
m=[24,25,27]
n=len(m)
midpos=n//2
print(m[0:])
print('len:',n)
print('Mid Pos:',midpos) 
print('Value of Mid Pos:',m[midpos])
# Out:
# [24, 25, 27]
# len: 3
# Mid Pos: 1
# Value of Mid Pos: 25

# %%
m=[40,42,45,47,49]
n=len(m)
midpos=n//2
print(m[0:])
print('len:',n)
print('Mid Pos:',midpos) 
print('Value of Mid Pos:',m[midpos])
# Out:
# [40, 42, 45, 47, 49]
# len: 5
# Mid Pos: 2
# Value of Mid Pos: 45
