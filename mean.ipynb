# %%
a=[1,4,6,9,6]
a_sum=sum(a)
print("sum:",a_sum)
print("count:",len(a))
# Out:
# sum: 26
# count: 5

# %%
b=[14,42,17,19,66,87]
x=sum(b)
y=len(b)
print("sum:",x)
print("count:",y)
# Out:
# sum: 245
# count: 6

# %%
#Mean

p=[24,73,56,28,23,15,17,34,71,77]
x=sum(p)
y=len(p)
z=x/y
print("sum:",x)
print("count:",y)
print("Mean:",z)
# Out:
# sum: 418
# count: 10
# Mean: 41.8

# %%
q=[24,73,56,28,23,15,17,71]
x=sum(q)
y=len(q)
z=x/y
print("sum:",x)
print("count:",y)
print("Mean:",z)
# Out:
# sum: 307
# count: 8
# Mean: 38.375

# %%
a=[3,6,4,8]
x=sum(a)
print("sum:",x)
# Out:
# sum: 21

# %%
a=[3,56,28,23]
x=len(a)
y=sum(a)
z=y/x
print("Mean:",z)
# Out:
# Mean: 27.5
